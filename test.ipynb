# %%
import platform
platform.python_implementation()
# Out:
# 'CPython'

# %%
import pstats

# Load the profile output
profiler_stats = pstats.Stats('profiling_result.prof')

with open('profiling_results_using_simpleEngineClass.txt', 'w') as stream:
    stats = pstats.Stats('profiling_result.prof', stream=stream)
    stats.sort_stats(pstats.SortKey.CUMULATIVE) ##
    stats.print_stats()
# Sort the statistics by cumulative time
profiler_stats.sort_stats(pstats.SortKey.CUMULATIVE)

# Print the sorted profile statistics
profiler_stats.print_stats()
# Out:
# Tue Jun 27 21:54:29 2023    profiling_result.prof
#
#          1976220 function calls (1971581 primitive calls) in 3.383 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      65/1    0.001    0.000    3.383    3.383 {built-in method builtins.exec}
#         1    0.000    0.000    3.383    3.383 chesstest6.py:1(<module>)
#         1    0.000    0.000    3.059    3.059 chesstest6.py:54(best_move_algorithm)
#         1    0.000    0.000    3.059    3.059 chesstest6.py:69(iterative_deepening)
#         3    0.000    0.000    3.059    1.020 chesstest6.py:83(MTDF)
#    3726/6    0.023    0.000    3.059    0.510 chesstest6.py:101(alpha_beta_with_memory)
#      2536    0.028    0.000    2.251    0.001 chesstest6.py:160(evaluation)
#      2536    0.016    0.000    2.212    0.001 C:\Users\trung\anaconda3\envs\ChessAIProject\lib\site-packages\chess\engine.py:2394(analyse)
# ...
