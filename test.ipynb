# %%
import platform
platform.python_implementation()
# Out:
# 'CPython'

# %%
import pstats

# Load the profile output
profiler_stats = pstats.Stats('output.txt')

# Sort the statistics by cumulative time
profiler_stats.sort_stats(pstats.SortKey.CALLS)

# Print the sorted profile statistics
profiler_stats.print_stats()
# Out:
# Thu Jun 15 13:50:55 2023    output.txt
#
#          9494052 function calls (9374525 primitive calls) in 84.553 seconds
#
#    Ordered by: call count
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    290328    0.104    0.000    0.104    0.000 C:\Users\trung\anaconda3\envs\ChessAIProject\lib\site-packages\chess\__init__.py:627(piece_type_at)
#    276851    0.161    0.000    0.186    0.000 C:\Users\trung\anaconda3\envs\ChessAIProject\lib\site-packages\chess\__init__.py:214(scan_reversed)
#    268247    0.033    0.000    0.033    0.000 {method 'append' of 'list' objects}
#    212946    0.028    0.000    0.028    0.000 {method 'bit_length' of 'int' objects}
#    203750    0.030    0.000    0.030    0.000 {method 'pop' of 'list' objects}
#    193623    0.090    0.000    0.090    0.000 C:\Users\trung\anaconda3\envs\ChessAIProject\lib\site-packages\chess\__init__.py:446(__init__)
# ...
